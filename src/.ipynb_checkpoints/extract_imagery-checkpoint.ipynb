# %% [markdown]
# # Crop Loss Prediction Project

# %%
# Imports
import descarteslabs as dl
from datetime import datetime
import sys
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from datetime import date
import shapefile
import numpy as np

# %%
# Methods
def filter_duplicates(items):
    # Removing duplicate consecutive coordinates in a polygon
    for item in items:
        prev = None
        for i in item:
            if i != prev:
                yield i 
                prev = i
            
def search_scenes(geom, product, start_datetime, end_datetime):
    # Searching for scenes of a specific satellite product over `geom` and within the datetimes entered
    scenes, ctx = dl.scenes.search(geom,
                                   products=product,
                                   start_datetime = start_datetime,
                                   end_datetime = end_datetime
                                   )    
    return scenes, ctx

def read_aoi_shapefile(filename, country):
    # Reading the shapefile with all AOIs, and convert them to a dataframe
    shapes = shapefile.Reader(filename)
    aois = shapes.shapeRecords()
    if country == 'Malawi':
        col_names = ["y3_hhid", "gardenid", "plotid", "coordinates"]
        df = pd.DataFrame(index=np.arange(0, len(aois)), columns = col_names)
        for i, r in enumerate(aois):
            df.at[i] = [r.record[0], r.record[1], r.record[2], np.nan]
            df.at[i, "coordinates"] = [r.shape.__geo_interface__['coordinates'][0]]
    elif country == 'Ethiopia':
        
        col_names = ["h_id", "hh_id", "parcel_id", "field_id", "coordinates"]
        df = pd.DataFrame(index=np.arange(0, len(aois)), columns = col_names)
        for i, r in enumerate(aois):
            df.at[i] = [str(r.record[0]) + str(r.record[1]),
                        str(r.record[2]) + str(r.record[3]),
                        r.record[4],
                        r.record[5],
                        np.nan]
            df.at[i, "coordinates"] = [r.shape.__geo_interface__['coordinates'][0]]
        
    return df

def extract_sat_reflectance(lsms_df,
                            aois_df, 
                            product_name,
                            bands,
                            resolution,
                            start_datetime,
                            end_datetime, 
                            country):
    
    
    samples_df = pd.DataFrame(columns = lsms_df.columns)

    geom = {
        "type": "Polygon",
        "coordinates": [
        ]
    }
    
    # Looping over AOI polygons
    for i_plot in range(0, 20):#lsms_df.shape[0]):
        
        if country == 'Malawi':
            y3_hhid = lsms_df["y3_hhid"][i_plot]
            gardenid = lsms_df["gardenid"][i_plot]
            plotid = lsms_df["plotid"][i_plot]

            aoi = aois_df.loc[(aois_df['y3_hhid'] == y3_hhid)
                        & (aois_df['gardenid'] == gardenid)
                        & (aois_df['plotid'] == plotid)]
        elif country == 'Ethiopia':
            h_id = lsms_df["h_id"][i_plot]
            hh_id = lsms_df["hh_id"][i_plot]
            parcel_id = lsms_df["parcel_id"][i_plot]
            field_id = lsms_df["field_id"][i_plot]

            aoi = aois_df.loc[(aois_df['h_id'] == h_id)
                        & (aois_df['hh_id'] == hh_id)
                        & (aois_df['parcel_id'] == parcel_id)
                        & (aois_df['field_id'] == field_id)]
        
        if not aoi.empty:
            coors = list()
            coor = aoi.iloc[0]["coordinates"]
            coors.insert(0, tuple(filter_duplicates(coor)))
            geom['coordinates'] = coors
            scenes, ctx = search_scenes(geom, product_name, start_datetime, end_datetime)

            ctx.assign(resolution = resolution)
            arr = scenes[-1].ndarray(bands[0], ctx)

            sample = lsms_df.iloc[i_plot].copy()
            sample.loc['datetime'] = list(scenes.each.properties['acquired'])
            
            # Extracing band information for each scene
            for band in bands:
                data = np.empty((arr.data.shape[1], arr.data.shape[2], len(scenes)))
                for scene in range(0, len(scenes)):
                    band_scale = list(scenes.each.properties.bands.blue.data_range)[0][1]
                    arr = scenes[scene].ndarray(band, ctx)
                    band_data = arr.data / band_scale
                    band_data[arr.mask] = np.nan
                    data[:, :, scene] = np.squeeze(band_data.swapaxes(0, 1).swapaxes(1, 2))#.reshape(-1, arr.data.shape[0])
                sample.loc[band] = data
            
            
            # Extracing cloud mask
            data = np.empty((arr.data.shape[1], arr.data.shape[2], len(scenes)))
            for scene in range(0, len(scenes)):
                arr = scenes[scene].ndarray('cloud-mask', ctx)
                band_data = arr.data
                data[:, :, scene] = np.squeeze(band_data.swapaxes(0, 1).swapaxes(1, 2))#.reshape(-1, arr.data.shape[0])
            sample.loc['cloud-mask'] = data

            samples_df = samples_df.append(sample)
    
    # Removing columns with geolocation info
    if country == 'Malawi':
        samples_df = samples_df.drop(columns=["y3_hhid", "gardenid", "plotid", "hh_gps_lat", "hh_gps_long"])
    elif country == 'Ethiopia':
        samples_df = samples_df.drop(columns=["h_id", "hh_id", "parcel_id", "field_id", "hh_gps_lat", "hh_gps_long"])
        
    return samples_df

# %% [markdown]
# ## Malawi Case Study

# %% [markdown]
# ### Reading survery data

# %%
lsms_malawi_filename = '/home/ec2-user/crop-loss-EPAR/data/Malawi Survey Responses EPAR Radiant 2Sigma.csv'
lsms_malawi_df = pd.read_csv(lsms_malawi_filename)
lsms_malawi_df.head()
# Out:
#     y3_hhid gardenid plotid  crop_loss  crop_loss_reason_rain_excess  \
# 0  0001-002     RG01    R01        NaN                           NaN
# 1  0001-002     RG02    R01        NaN                           NaN
# 2  0001-002     RG03    R01        NaN                           NaN
# 3  0001-002      NaN    NaN        NaN                           NaN
# 4  0003-001     RG01    R01        NaN                           NaN
#
#    crop_loss_reason_rain_little  crop_loss_reason_insects  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#    crop_loss_reason_disease  crop_loss_reason_weeds  crop_loss_reason_hail  \
# 0                       NaN                     NaN                    NaN
# 1                       NaN                     NaN                    NaN
# 2                       NaN                     NaN                    NaN
# 3                       NaN                     NaN                    NaN
# 4                       NaN                     NaN                    NaN
#
#     ...    plot_twi  hh_gps_lat  hh_gps_long  annual_temp  annual_precip  \
# 0   ...          12    -9.50446      33.2302        212.0         1367.0
# 1   ...          12    -9.50446      33.2302        212.0         1367.0
# 2   ...          12    -9.50446      33.2302        212.0         1367.0
# 3   ...         NaN         NaN          NaN          NaN            NaN
# 4   ...          13    -9.50446      33.2302        212.0         1374.0
#
#       ea_id  region  district  ta_code  reside
# 0  10101215   North   Chitipa        1   RURAL
# 1  10101215   North   Chitipa        1   RURAL
# 2  10101215   North   Chitipa        1   RURAL
# 3  10101215   North   Chitipa        1   RURAL
# 4  10101215   North   Chitipa        1   RURAL
#
# [5 rows x 72 columns]

# %% [markdown]
# ### Reading AOIs

# %%
# Reading the shapefile to a dataframe with three IDs, and coordinates
# Data cleanings that are done outside of this notebook:
# Duplicate entries are cleaned, missing data are removed
aoi_malawi_filename = '/home/ec2-user/crop-loss-EPAR/data/Malawi_LSMS_Enumeration_Areas_100m_Example.shp'

# %%
aois_malawi_df = read_aoi_shapefile(aoi_malawi_filename, country = 'Malawi')

# %%
aois_malawi_df.head()
# Out:
#     y3_hhid gardenid plotid                                        coordinates
# 0  0001-002     RG01    R01  [((33.231098, -9.50446), (33.231098, -9.50446)...
# 1  0001-002     RG02    R01  [((33.231098, -9.50446), (33.231098, -9.50446)...
# 2  0001-002     RG03    R01  [((33.231098, -9.50446), (33.231098, -9.50446)...
# 3  0003-001     RG01    R01  [((33.231098, -9.50446), (33.231098, -9.50446)...
# 4  0003-001     RG02    R01  [((33.231098, -9.50446), (33.231098, -9.50446)...

# %% [markdown]
# ### Extracting Satellite Imagery data

# %%
# Extracting Landsat-8 Data
# Takes 5-10 minutes 
malawi_start = "2015-12-01"
malawi_end = "2016-04-30"

malawi_l8_bands = ["blue", "green", "red", "nir", "swir1", "swir2"]

malawi_l8_df = extract_sat_reflectance(lsms_df = lsms_malawi_df,
                        aois_df = aois_malawi_df,
                        product_name = "landsat:LC08:PRE:LaSRC",
                        bands = malawi_l8_bands,
                        resolution = 30,
                        start_datetime = malawi_start,
                        end_datetime = malawi_end, 
                        country = 'Malawi')

# %%
malawi_l8_df.head()

# %%
# Extracting Sentinel-2 Data
# Data in Blue, Green, Red and NIR come at 10 m spatial resolution.
# Other bands like SWIR and Red-Edge are at 20 m. 
# In this case we are only extracting the 10 m data, but we can extract the 20 m ones as well
# and then downscale (interpolate) them to 10 m. 

# Takes 5-10 minutes 
malawi_start = "2015-12-01"
malawi_end = "2016-04-30"

malawi_s2_bands = ["blue", "green", "red", "nir"]

malawi_s2_df = extract_sat_reflectance(lsms_df = lsms_malawi_df,
                        aois_df = aois_malawi_df,
                        product_name = "sentinel-2:L1C",
                        bands = malawi_s2_bands,
                        resolution = 10,
                        start_datetime = malawi_start,
                        end_datetime = malawi_end,
                        country = 'Ethiopia')

# %%
malawi_s2_df.head()

# %% [markdown]
# ### Export data to csv

# %%
# Landsat-8 Export
malawi_l8_df.to_csv('/home/ec2-user/crop-loss-EPAR/exports/malawi_l8_data.csv', index=False)

# %%
# Sentinel-2 Export
malawi_s2_df.to_csv('/home/ec2-user/crop-loss-EPAR/exports/malawi_s2_data.csv', index=False)

# %% [markdown]
# ### Visualize Sample Output

# %%
# Landsat-8 Example
sample_band = malawi_l8_df.iloc[0]['swir2'][:, :, 2]
c = plt.imshow(sample_band)

# %%
# Sentinel-2 Example
sample_band_red = malawi_s2_df.iloc[10]['red'][:, :, 10]
c = plt.imshow(sample_band_red)

# %% [markdown]
# ## Ethiopia Case Study

# %% [markdown]
# ### Reading Survey Data

# %%
lsms_ethiopia_filename = '/home/ec2-user/crop-loss-EPAR/data/Ethiopia/Ethiopia No Missing/Ethiopia Survey Responses EPAR Radiant 2Sigma_clean.csv'
lsms_ethiopia_df = pd.read_csv(lsms_ethiopia_filename)
lsms_ethiopia_df["holder_id"].astype(int)
lsms_ethiopia_df.insert(0, "h_id", lsms_ethiopia_df["holder_id"].map(str) + lsms_ethiopia_df["holder_id_"].map(str))
lsms_ethiopia_df.insert(1, "hh_id", lsms_ethiopia_df["household_"].map(str) + lsms_ethiopia_df["househol_1"].map(str))
lsms_ethiopia_df.drop(columns=['holder_id', 'holder_id_', 'household_', 'househol_1'])
lsms_ethiopia_df.head()
# Out:
#              h_id              hh_id  holder_id  holder_id_  household_  \
# 0  10101016100201  10101088801601000   10101016      100201    10101088
# 1  10101016100201  10101088801601000   10101016      100201    10101088
# 2  10101016100201  10101088801601000   10101016      100201    10101088
# 3  10101016100201  10101088801601000   10101016      100201    10101088
# 4  10101016101701  10101088801601000   10101016      101701    10101088
#
#    househol_1  parcel_id  field_id  area_planted_with_crop  \
# 0   801601000          1         1                     NaN
# 1   801601000          1         4                     NaN
# 2   801601000          1         2                     NaN
# 3   801601000          1         3                     NaN
# 4   801601000          1         5                     NaN
#
#    area_harvested_with_crop   ...    crop_loss_ha  third_crop_planted  \
# 0                       NaN   ...             NaN                 NaN
# 1                      75.0   ...             NaN                 NaN
# 2                      67.0   ...             NaN                 NaN
# 3                      33.0   ...             NaN                 NaN
# 4                       NaN   ...             NaN                 NaN
#
#    fourth_crop_planted  fifth_crop_planted  annual_temp  annual_precip  \
# 0                  NaN                 NaN          264            699
# 1                  NaN                 NaN          264            699
# 2                  NaN                 NaN          264            699
# 3                  NaN                 NaN          264            699
# 4                  NaN                 NaN          263            700
#
#       ea_lat     ea_lon  entire_plot_planted  season
# 0  14.353816  37.890876                  NaN     NaN
# 1  14.353816  37.890876                  NaN     NaN
# 2  14.353816  37.890876                  NaN     NaN
# 3  14.353816  37.890876                  NaN     NaN
# 4  14.353816  37.890876                  NaN     NaN
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Reading AOIs

# %%
# Takes ~1 minute 

# Reading the shapefile to a dataframe with six IDs, and coordinates
# Data cleanings that are done outside of this notebook:
# Duplicate entries are cleaned, missing data are removed

aoi_ethiopia_filename = '/home/ec2-user/crop-loss-EPAR/data/Ethiopia/Ethiopia No Missing/Ethiopia_LSMS_Enumeration_Areas_100m.shp'
aois_ethiopia_df = read_aoi_shapefile(aoi_ethiopia_filename, country = 'Ethiopia')

# %%
aois_ethiopia_df.head()
# Out:
#              h_id              hh_id parcel_id field_id  \
# 0  10101016100201  10101088801601000         1        1
# 1  10101016100201  10101088801601000         1        4
# 2  10101016100201  10101088801601000         1        2
# 3  10101016100201  10101088801601000         1        3
# 4  10101016101701  10101088801601000         1        5
#
#                                          coordinates
# 0  [((37.89170931, 14.35381619), (37.89170931, 14...
# 1  [((37.89170931, 14.35381619), (37.89170931, 14...
# 2  [((37.89170931, 14.35381619), (37.89170931, 14...
# 3  [((37.89170931, 14.35381619), (37.89170931, 14...
# 4  [((37.89170931, 14.35381619), (37.89170931, 14...

# %% [markdown]
# ### Extracting Satellite Imagery data

# %%
# Extracting Landsat-8 Data

# Takes 5-10 minutes 
ethiopia_start = "2015-12-01"
ethiopia_end = "2016-04-30"

ethiopia_l8_bands = ["blue", "green", "red", "nir", "swir1", "swir2"]

ethiopia_l8_df = extract_sat_reflectance(lsms_df = lsms_ethiopia_df,
                                aois_df = aois_ethiopia_df,
                                product_name = "landsat:LC08:PRE:LaSRC",
                                bands = ethiopia_l8_bands,
                                resolution = 30,
                                start_datetime = ethiopia_start,
                                end_datetime = ethiopia_end, 
                                country = 'Ethiopia')

# %% [markdown]
# ### Export data to csv

# %%
ethiopia_l8_df.to_csv('/home/ec2-user/crop-loss-EPAR/exports/ethiopia_l8_data.csv', index=False)

# %% [markdown]
# ### Visualize Sample Output

# %%
# Landsat-8 Example
sample_band = ethiopia_l8_df.iloc[0]['red'][:, :, 2]
c = plt.imshow(sample_band)
